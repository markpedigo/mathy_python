# %% [markdown]
# # Lists and Tuples

# %% [markdown]
# ## Creating lists

# %%
scores = [88, 92, 75, 100, 84]

# %%
names= ['Alice', 'Bob', 'Carol']

# %%
mixed = [1, 'Mathy Python', 3.14, True]

# %%
empty = []

# %%
matrix = [ [1, 2, 3],
           [4, 5, 6],
           [7, 8, 9]]

# %%
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ## Indexing and Slicing

# %%
scores
# Out:
# [88, 92, 75, 100, 84]

# %%
scores[0]
# Out:
# 88

# %%
scores[-1]
# Out:
# 84

# %%
scores[1:3]
# Out:
# [92, 75]

# %%
scores[:3]
# Out:
# [88, 92, 75]

# %%
scores[2:]
# Out:
# [75, 100, 84]

# %%
scores[::-1]
# Out:
# [84, 100, 75, 92, 88]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][1]
# Out:
# 2

# %% [markdown]
# ## Mutability

# %%
scores
# Out:
# [88, 92, 75, 100, 84]

# %%
scores[2] = 95

# %%
scores
# Out:
# [88, 92, 95, 100, 84]

# %% [markdown]
# ### The aliasing gotcha!

# %%
a = [1, 2, 3]

# %%
b = a

# %%
b
# Out:
# [1, 2, 3]

# %%
b[0] = 99

# %%
b
# Out:
# [99, 2, 3]

# %%
a
# Out:
# [99, 2, 3]

# %%
a = [1, 2, 3]

# %%
b = a.copy()

# %%
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
b[0] = -999

# %%
b
# Out:
# [-999, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Common list operations

# %%
len(scores)
# Out:
# 5

# %%
scores.append(91)

# %%
scores
# Out:
# [88, 92, 95, 100, 84, 91]

# %%
scores.insert(0, 70)

# %%
scores
# Out:
# [70, 88, 92, 95, 100, 84, 91]

# %%
scores + [88, 70]
# Out:
# [70, 88, 92, 95, 100, 84, 91, 88, 70]

# %%
scores.remove(88)

# %%
scores
# Out:
# [70, 92, 95, 100, 84, 91]

# %%
scores.pop()
scores
# Out:
# [70, 92, 95, 100, 84]

# %%
scores.pop()
# Out:
# 84

# %%
scores.pop(0)
# Out:
# 70

# %%
scores
# Out:
# [92, 95, 100]

# %%
del scores[1]

# %%
scores
# Out:
# [92, 100]

# %%
scores.sort()

# %%
scores
# Out:
# [92, 100]

# %%
scores.sort(reverse=True)

# %%
scores
# Out:
# [100, 92]

# %%
scores = scores + [99, 87, 78, 77]
scores
# Out:
# [100, 92, 99, 87, 78, 77]

# %%
scores = scores + [23, 34, 99, 65]
scores
# Out:
# [100, 92, 99, 87, 78, 77, 23, 34, 99, 65]

# %%
sorted(scores)
# Out:
# [23, 34, 65, 77, 78, 87, 92, 99, 99, 100]

# %%
scores
# Out:
# [100, 92, 99, 87, 78, 77, 23, 34, 99, 65]

# %%
new_sorted = sorted(scores)
print(new_sorted)
print(scores)
# Out:
# [23, 34, 65, 77, 78, 87, 92, 99, 99, 100]
# [100, 92, 99, 87, 78, 77, 23, 34, 99, 65]

# %%
sum(scores)
# Out:
# 754

# %%
min(scores)
# Out:
# 23

# %%
max(scores)
# Out:
# 100

# %%
sum(scores) / len(scores)
# Out:
# 75.4

# %%
100 in scores
# Out:
# True

# %%
55 in scores
# Out:
# False

# %%
scores.count(99)
# Out:
# 2

# %%
scores
# Out:
# [100, 92, 99, 87, 78, 77, 23, 34, 99, 65]

# %%
scores.index(100)
# Out:
# 0

# %%
scores.index(120)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 scores.index(120)
#
# ValueError: 120 is not in list

# %% [markdown]
# ## Building a list - a useful pattern

# %%
evens = []
for n in range(10):
    if n % 2 == 0:  # is n even?
        evens.append(n)
evens
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# ## Tuples

# %%
point = (3, 4)
rgb = (155, 128, 0)
singleton = (42,)

# %%
point
# Out:
# (3, 4)

# %%
rgb
# Out:
# (155, 128, 0)

# %%
singleton
# Out:
# (42,)

# %%
point[0]
# Out:
# 3

# %%
rgb[1:]
# Out:
# (128, 0)

# %%
point[0] = 99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 point[0] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
point = (3, 4)
x, y = point
print('x', x)
print('y', y)
# Out:
# x 3
# y 4

# %%
x, y, z = point
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 x, y, z = point
#
# ValueError: not enough values to unpack (expected 3, got 2)
