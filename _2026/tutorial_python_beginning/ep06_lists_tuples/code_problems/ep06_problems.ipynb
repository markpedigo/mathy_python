# %% [markdown]
# <font size=6>Mathy Python</font>
#
# <font size=5>Episode 6 (Exercises / Puzzles): Lists and Tuples</font>

# %% [markdown]
# # TIER 1: Warmup

# %% [markdown]
# 1. Create a list of the first 10 perfect squares starting with 1. Access the first, last, and middle elements.

# %% [markdown]
# 2. Given:
# ```python
# temps = [72, 68, 75, 80, 65, 70, 78]
# ```
# Find the highest, lowest, and average temperature using built-in functions.

# %% [markdown]
# 3. Without running it first, predict what this prints. Then check.
# ```python
# a = [1, 2, 3, 4, 5]
# print(a[1:4])
# print(a[::-1])
# print(a[::2])
# ```

# %% [markdown]
# Predictions:

# %%
a = [1, 2, 3, 4, 5]
print(a[1:4])
print(a[::-1])
print(a[::2])

# %% [markdown]
# 4. Given a list of five numbers, sort it in descending order using both `sorted()` and `.sort()`. What is the difference between the two?

# %% [markdown]
# 5. Create a tuple of the RGB values for your favorite color. Unpack it into three variables and print each one.

# %% [markdown]
# # TIER 2: Intermediate

# %% [markdown]
# 6. Given:
# ```python
# a = [1, 2, 3]
# b = a
# b.append(4)
# print(a)
# print(b)
# ```
# Predict the output before running it. Then fix the code so that `a` remains `[1, 2, 3]` after appending to `b`.

# %% [markdown]
# Predictions:

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)

# %%
# fix

# %% [markdown]
# 7. Given:
# ```python
# scores = [88, 92, 75, 100, 84, 92, 75, 88]
# ```
# Without using a loop, remove all duplicate scores and return them in ascending order.

# %% [markdown]
# 8. Given a list of (name, score) tuples:
# ```python
# results = [('Alice', 92), ('Bob', 75), ('Carol', 88), ('Dave', 100), ('Eve', 84)]
# ```
# Unpack each tuple and print a formatted line for each student.

# %% [markdown]
# 9. Given:
# ```python
# matrix = [[1, 2, 3],
#           [4, 5, 6],
#           [7, 8, 9]]
# ```
# Access the value 5. Then extract the entire middle row and the entire middle column as separate lists.

# %% [markdown]
# 10. Given two lists:
# ```python
# names = ['Alice', 'Bob', 'Carol', 'Dave', 'Eve']
# scores = [88, 92, 75, 100, 84]
# ```
# Produce a single sorted list of (score, name) tuples, sorted by score from highest to lowest.

# %% [markdown]
# # TIER 3: Challenge

# %% [markdown]
# 11. **Running total.** Given a list of daily expenses:
# ```python
# expenses = [32.50, 18.75, 45.00, 12.25, 67.80, 23.40, 55.10]
# ```
# Build a new list where each element is the running total up to that day. The last element should equal `sum(expenses)`.

# %% [markdown]
# 12. **List rotation.** Write code that rotates a list by n positions to the right. For example, rotating `[1, 2, 3, 4, 5]` by 2 gives `[4, 5, 1, 2, 3]`. Using only slicing, no loops.

# %% [markdown]
# 13. **Flatten a nested list.** Given:
# ```python
# nested = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# ```
# Produce a single flat list `[1, 2, 3, 4, 5, 6, 7, 8, 9]` using a loop and `.extend()`.

# %% [markdown]
# 14. **Second largest.** Given a list of numbers with possible duplicates, find the second largest unique value without using `sorted()`.

# %% [markdown]
# 15. **Dot product.** Given two vectors as lists:
# ```python
# u = [1, 2, 3]
# v = [4, 5, 6]
# ```
# Compute their dot product ($u \cdot v = 1 \times 4 + 2 \times 5 + 3 \times 6 = 32$) using a loop.
