# %% [markdown]
# <font size=6>Mathy Python</font>
#
# <font size=5>Strings</font>

# %% [markdown]
# # TIER 1: Warmup

# %% [markdown]
# 1. **Slicing.** Given the string `s = 'Mathy Python'`, extract just the word `'Python'` using slicing.

# %% [markdown]
# 2. **Title Case.** Write a one-liner that takes any string and returns it in title case with leading and trailing whitespace removed. Test it on `'   mathy python   '`.

# %% [markdown]
# 3. **Count Characters.** How many times does the letter `'t'` appear in `'Mathy Python'`? Use a string method, not manual counting.

# %% [markdown]
# 4. **Slicing.** Without running it first, predict what this prints. Then check.
# ```python
# s = 'Mathy Python'
# print(s[0])
# print(s[-1])
# print(s[::2])
# print(s[::-1])
# ```

# %% [markdown]
# Prediction:

# %% [markdown]
# 5. **f-strings.** Use an f-string to print the following, using variables for each value:
# ```
# The area of a circle with radius 7 is 153.94.
# ```

# %% [markdown]
# # TIER 2: Intermediate

# %% [markdown]
# 6. **Extract substrings.** Given a full name as a single string (e.g. `'Mark Pedigo'`), extract the first name and last name into separate variables using a string method. Then print them in reverse order: last name first, comma, then first name.

# %% [markdown]
# 7. **String validation.** A user enters a number as a string. Write code that checks whether the string represents a valid integer before converting it. Hint: look up the `str.isdigit()` method using `help()` or `?`.

# %% [markdown]
# 8. **String reversal.** Without using `replace()`, reverse just the first word in `'Mathy Python'`. The result should be `'yhtaM Python'`.

# %% [markdown]
# 9. **Split a string.** Given this string:
# ```python
# data = 'Alice,92,A;Bob,75,C;Carol,88,B'
# ```
# Split it into individual records, then split each record into fields. Print each student's name and score on its own line. Hint: You'll need string methods `.split()` and `.join()`.

# %% [markdown]
# 10. **f-string formatting** Format the output of problem 9 into a table:

# %% [raw]
# Name      Score     Grade
# Alice     92        A
# Bob       75        C
# Carol     88        B

# %% [markdown]
# Hint: Look up string formatting [here](https://docs.python.org/3/tutorial/inputoutput.html#formatted-string-literals).

# %% [markdown]
# # TIER 3: Challenge

# %% [markdown]
# 11. **Palindrome checker.** Write code that checks whether a string is a palindrome -- reads the same forwards and backwards -- ignoring spaces and case. Test it on `'racecar'`, `'A man a plan a canal Panama'`, and `'Mathy Python'`.

# %% [markdown]
# 12. **Caesar cipher, decrypted.** You receive this encrypted message:
# ```
# Pdwkb Sbwkrq lv ixq
# ```
# It was encrypted with a Caesar cipher using a shift of 3. To decrypt it, loop over each character, shift it back by 3 mod 26, and rebuild the string. Preserve spaces and punctuation. What does it say?

# %% [markdown]
# 13. **Word frequency.** Given any sentence string, count how many times each unique word appears, ignoring case and punctuation. Print the results. Test it on a sentence of your choice.
