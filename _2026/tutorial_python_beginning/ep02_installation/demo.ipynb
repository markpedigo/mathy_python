# %% [markdown]
# # Demo Notebook

# %%
print("Hello, world.")
# Out:
# Hello, world.

# %%
print("This is the episode where we install Jupyter.")
# Out:
# This is the episode where we install Jupyter.
