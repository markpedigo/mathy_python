# %% [markdown]
# # Names, values, and types

# %% [markdown]
# ## Sample Program

# %%
name = input('What is your name?')
age = int(input('How old are you?'))

seconds = age * 365 * 24 * 60 * 60

print('Hello,', name)
print('You have lived for approximately', seconds, 'seconds.')
# Out:
# What is your name? Mark
# How old are you? 29
# Hello, Mark
# You have lived for approximately 914544000 seconds.

# %% [markdown]
# ## Variables

# %%
city = 'Minneapolis'

# %%
city
# Out:
# 'Minneapolis'

# %%
type(city)
# Out:
# str

# %%
temp_f = 79

# %%
temp_f
# Out:
# 79

# %%
type(temp_f)
# Out:
# int

# %%
Temp_f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 Temp_f
#
# NameError: name 'Temp_f' is not defined

# %% [markdown]
# # Naming Rules in Python

# %% [markdown]
# * Names must start with a letter or underscore (_)
# * After that, letters, digits, and underscores are fine
# * Case matters; e.g., temp_f, Temp_f are different
# * By convention, use snake_case

# %% [markdown]
# # Types

# %%
type(42)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### Gotcha!

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %% [markdown]
# ### Division

# %%
5 / 2
# Out:
# 2.5

# %%
4 / 2
# Out:
# 2.0

# %%
3.1 / 2
# Out:
# 1.55

# %%
5 // 2
# Out:
# 2

# %% [markdown]
# ## Dynamic Typing

# %%
thing = 42

# %%
thing
# Out:
# 42

# %%
type(thing)
# Out:
# int

# %%
thing = 3.14

# %%
thing
# Out:
# 3.14

# %%
type(thing)
# Out:
# float

# %%
thing = 'hello'

# %%
thing
# Out:
# 'hello'

# %%
type(thing)
# Out:
# str

# %%
my_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 my_var
#
# NameError: name 'my_var' is not defined

# %%
my_var = 45

# %%
my_var
# Out:
# 45

# %% [markdown]
# ## Type casting

# %%
int(1.7)
# Out:
# 1

# %%
int(True)
# Out:
# 1

# %%
float(42)
# Out:
# 42.0

# %%
str(9.99)
# Out:
# '9.99'

# %%
str(9.99) / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 str(9.99) / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
int('42')
# Out:
# 42

# %%
int('dog')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 int('dog')
#
# ValueError: invalid literal for int() with base 10: 'dog'

# %%
int('1.1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 int('1.1')
#
# ValueError: invalid literal for int() with base 10: '1.1'

# %%
int(float('1.1'))
# Out:
# 1
