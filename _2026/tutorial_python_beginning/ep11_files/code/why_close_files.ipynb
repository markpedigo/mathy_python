# %% [markdown]
# # Why bother to close files?

# %% [markdown]
# * Buffer: Writes may not reach disk until close
# * File handles are a limited resource
# * The OS cleans up on exit, but not always soon enough

# %% [markdown]
# ## The fix: always use `with`
# * `with open(...) as f:` closes the file the moment the block ends, guaranteed, even if something goes wrong inside. You never have to remember to close it.
