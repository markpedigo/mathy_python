# %% [markdown]
# <font size=6>Mathy Python</font>
#
# <font size=5>Episode 1 (Problems and Puzzles): You Already Know More Python Than You Think You Do</font>

# %% [markdown]
# # TIER 1: Warmup

# %% [markdown]
# 1. Type `print("Hello, world.")` into a cell and run it. Then modify it to print your own name.

# %% [markdown]
# 2. Use Python as a calculator to compute:
# - $23 + 47$
# - $100 - 37$
# - $12 \times 8$
# - $100 / 4$

# %% [markdown]
# 3. What is $2^{10}$? Use Python to find out. What operator did you use?

# %% [markdown]
# 4. What is the remainder when 17 is divided by 5? What operator gives you the remainder in Python?

# %% [markdown]
# 5. Does Python follow the standard order of operations? Test it:
# - $2 + 3 \times 4$
# - $(2 + 3) \times 4$

# %% [markdown]
# # TIER 2: Intermediate

# %% [markdown]
# 6. Without running it first, predict the result of each expression. Then check.
# ```python
# 10 // 3
# 10 % 3
# 10 // 3 * 3 + 10 % 3
# ```

# %% [markdown]
# 7. A pizza costs \$12.99 and you're buying 4 of them. Use Python to compute the total cost, the tax (assume 8%), and the final amount due. Print each on its own line.

# %% [markdown]
# 8. You drive 240 miles on 8 gallons of gas. Use Python to compute your fuel efficiency in miles per gallon. Then compute how many gallons you'd need for a 500-mile trip at the same efficiency.

# %% [markdown]
# 9. Compute the area and circumference of a circle with radius 5. Use `3.14159` for π. How close are your answers to what you'd get with a more precise value of π?

# %% [markdown]
# 10. The speed of light is approximately 299,792,458 meters per second. Use Python to compute how far light travels in one minute, one hour, and one day. Express your answers in kilometers.

# %% [markdown]
# # TIER 3: Challenge

# %% [markdown]
# 11. **Tip calculator.** A restaurant bill is \$47.35. Compute the tip and total for 15%, 18%, and 20% tip rates. Print each result on its own line, labeled clearly.

# %% [markdown]
# 12. **Unit converter.** 1 mile = 1.60934 kilometers. Compute how many kilometers are in 5 miles, 26.2 miles (a marathon), and 100 miles. Then compute how many miles are in 10 kilometers, 42.195 kilometers, and 100 kilometers.

# %% [markdown]
# **Problem 13: Compound interest.** You invest \\$5,000 at 6% annual interest, compounded annually. The balance after $n$ years is given by:
#
# $$B = P(1 + r)^n$$
#
# where $P$ is the principal, $r$ is the annual interest rate, and $n$ is the number of years.
#
# Using only arithmetic operators (no loops, no functions), compute the balance after 1, 5, 10, and 20 years.
#
# The Rule of 72 is a mental math shortcut for estimating doubling time: divide 72 by the annual interest rate expressed as a percentage. At 6%, the Rule of 72 predicts doubling in $72 / 6 = 12$ years. Verify this estimate by computing balances year by year until the balance first exceeds $2 \times P$. How close was the Rule of 72?

# %% [markdown]
# 14. **Gregorian calendar.** There are 365.2425 days in a year on average (accounting for leap years). Using only arithmetic operators, compute how many seconds are in a year, how many years are in a million seconds, and how many days old you are if you were born on January 1, 1969. Assume today is July 1, 2026.

# %% [markdown]
# 15. **Viète's formula.** The following product converges to $2/\pi$:
#
# $$\frac{2}{\pi} = \frac{\sqrt{2}}{2} \cdot \frac{\sqrt{2+\sqrt{2}}}{2} \cdot \frac{\sqrt{2+\sqrt{2+\sqrt{2}}}}{2} \cdots$$
#
# Using only `**` for square roots (recall $\sqrt{x} = x^{0.5}$), compute the first four terms of this product and estimate $\pi$. How accurate is your estimate?
